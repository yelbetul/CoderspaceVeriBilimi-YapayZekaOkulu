# %%
dosya = open("giderler.txt", "w")
dosya.write("Kira: 2,250.00TL \n")
dosya.close()

# %%
dosya = open("giderler.txt", "a")
dosya.write("Aidat: 350.00TL \n")
dosya.close()

# %%
dosya = open("giderler.txt", "a")
dosya.write("Elektrik: 250.00TL \n")
dosya.close()

# %%
dosya = open("giderler.txt", "r")  # herhangi bir şey belirtmezsek: open("giderler.txt")
# read()
# readline()
# readlines()

print(dosya.read())
# Out:
# Kira: 2,250.00TL
# Aidat: 350.00TL
# Elektrik: 250.00TL

# %%
dosya = open("giderler.txt", "r")  # herhangi bir şey belirtmezsek: open("giderler.txt")
print(dosya.readline())
print(dosya.readline())
print(dosya.readline())
# Out:
# Kira: 2,250.00TL
#
# Aidat: 350.00TL
#
# Elektrik: 250.00TL

# %%
dosya = open("giderler.txt", "r")  # herhangi bir şey belirtmezsek: open("giderler.txt")
print(dosya.readlines())
# Out:
# ['Kira: 2,250.00TL \n', 'Aidat: 350.00TL \n', 'Elektrik: 250.00TL \n']

# %%
dosya.close()

# %%
dosya2 = open("giderler.txt", "r+")
veri = dosya2.read()
dosya2.seek(0)  # dosyanın başına gel
dosya2.write("Eğitim: 12,250.00TL \n" + veri)
dosya2.close()

# %%
dosya2 = open("giderler.txt", "r+")
veri = dosya2.readlines()
veri.insert(2, "Doğalgaz: 150.00TL \n")
dosya2.seek(0)  # dosyanın başına gel
dosya2.writelines(veri)
dosya2.close()

# %%
import pandas as pd

# %%
veri = [['Ahmet', 10], ['Ayşe', 12], ['Fatma', 14], ['Mehmet', 11]]
df = pd.DataFrame(veri, columns = ['İsim', 'Yaş'])
print(df)
# Out:
#      İsim  Yaş
# 0   Ahmet   10
# 1    Ayşe   12
# 2   Fatma   14
# 3  Mehmet   11

# %%
veri = [['Ahmet', 10], ['Ayşe', 12], ['Fatma', 14], ['Mehmet', 11]]
df = pd.DataFrame(veri, columns = ['İsim', 'Yaş'], dtype = float)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 veri = [['Ahmet', 10], ['Ayşe', 12], ['Fatma', 14], ['Mehmet', 11]]
# ----> 2 df = pd.DataFrame(veri, columns = ['İsim', 'Yaş'], dtype = float)
#       3 print(df)
#
# File c:\Users\excal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:848, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     839         columns = ensure_index(columns)
#     840     arrays, columns, index = nested_data_to_arrays(
#     841         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     842         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     846         dtype,
#     847     )
# --> 848     mgr = arrays_to_mgr(
#     849         arrays,
#     850         columns,
#     851         index,
#     852         dtype=dtype,
# ...

# %%
veri2 = {'İsim':['Ahmet', 'Ayşe', 'Fatma', 'Mehmet'], 'Yaş':[10,12,14,11]}
df2 = pd.DataFrame(veri2)
print(df2)
# Out:
#      İsim  Yaş
# 0   Ahmet   10
# 1    Ayşe   12
# 2   Fatma   14
# 3  Mehmet   11

# %%
veri2 = {'İsim':['Ahmet', 'Ayşe', 'Fatma', 'Mehmet'], 'Yaş':[10,12,14,11]}
df2 = pd.DataFrame(veri2, index = ['I', 'II', 'III', 'IV'])
print(df2)
# Out:
#        İsim  Yaş
# I     Ahmet   10
# II     Ayşe   12
# III   Fatma   14
# IV   Mehmet   11

# %%
print(df2)
# Out:
#        İsim  Yaş
# I     Ahmet   10
# II     Ayşe   12
# III   Fatma   14
# IV   Mehmet   11

# %%
yeni_veri = {'ilk' : pd.Series([1, 2, 3], index = ['a', 'b', 'c']),
             'ikinci' : pd.Series([1, 2, 3, 4], index = ['a', 'c', 'b', 'd']),
             'üçüncü' : pd.Series([10, 20, 30], index = ['a', 'b', 'c'])}

df3 = pd.DataFrame(yeni_veri)
print(df3)
# Out:
#    ilk  ikinci  üçüncü
# a  1.0       1    10.0
# b  2.0       3    20.0
# c  3.0       2    30.0
# d  NaN       4     NaN

# %%
del df3['ilk']
print(df3)
# Out:
#    ikinci  üçüncü
# a       1    10.0
# b       3    20.0
# c       2    30.0
# d       4     NaN

# %%
df3.pop('üçüncü')
print(df3)
# Out:
#    ikinci
# a       1
# b       3
# c       2
# d       4

# %%
yeni_veri = {'ilk' : pd.Series([1, 2, 3], index = ['a', 'b', 'c']),
             'ikinci' : pd.Series([1, 2, 3, 4], index = ['a', 'c', 'b', 'd']),
             'üçüncü' : pd.Series([10, 20, 30], index = ['a', 'b', 'c'])}

df3 = pd.DataFrame(yeni_veri)
print(df3)
# Out:
#    ilk  ikinci  üçüncü
# a  1.0       1    10.0
# b  2.0       3    20.0
# c  3.0       2    30.0
# d  NaN       4     NaN

# %%
print(df3.loc['b'])
# Out:
# ilk        2.0
# ikinci     3.0
# üçüncü    20.0
# Name: b, dtype: float64

# %%
print(df3.iloc[1])
# Out:
# ilk        2.0
# ikinci     3.0
# üçüncü    20.0
# Name: b, dtype: float64

# %%
print(df3[1:3])
# Out:
#    ilk  ikinci  üçüncü
# b  2.0       3    20.0
# c  3.0       2    30.0

# %%
df4 = pd.DataFrame([[1,2],[3,4]], columns = ['a','b'])
df5 = pd.DataFrame([[5,6],[7,8]], columns = ['a','b'])
print(df4)
print("...")
print(df5)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# ...
#    a  b
# 0  5  6
# 1  7  8

# %%
df4 = df4.append(df5)
print(df4)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
df4 = df4.drop(0)
print(df4)
# Out:
#    a  b
# 1  3  4
# 1  7  8

# %%
import pandas as pd
veri_seti = {'İsim': pd.Series(['Ahmet', 'Mehmet', 'Ayşe', 'Fatma', 'Cevdet', 'Süleyman']),
             'Yaş': pd.Series([25, 26, 27, 25, 34, 32]),
             'Not': pd.Series([33.0, 67.2, 55.5, 67.8, 98.1, 66.2]),
             'Memleket': pd.Series(['Ankara', 'Konya', 'Denizli', 'Ankara', 'Ankara', 'Bursa'])}

df6 = pd.DataFrame(veri_seti)
print(df6)
# Out:
#        İsim  Yaş   Not Memleket
# 0     Ahmet   25  33.0   Ankara
# 1    Mehmet   26  67.2    Konya
# 2      Ayşe   27  55.5  Denizli
# 3     Fatma   25  67.8   Ankara
# 4    Cevdet   34  98.1   Ankara
# 5  Süleyman   32  66.2    Bursa

# %%
df6["Memleket"].value_counts()
# Out:
# Ankara     3
# Konya      1
# Bursa      1
# Denizli    1
# Name: Memleket, dtype: int64

# %%
print(df6.T)
# Out:
#                0       1        2       3       4         5
# İsim       Ahmet  Mehmet     Ayşe   Fatma  Cevdet  Süleyman
# Yaş           25      26       27      25      34        32
# Not         33.0    67.2     55.5    67.8    98.1      66.2
# Memleket  Ankara   Konya  Denizli  Ankara  Ankara     Bursa

# %%
print(df6.axes)
# Out:
# [RangeIndex(start=0, stop=6, step=1), Index(['İsim', 'Yaş', 'Not', 'Memleket'], dtype='object')]

# %%
print(df6.dtypes)
# Out:
# İsim         object
# Yaş           int64
# Not         float64
# Memleket     object
# dtype: object

# %%
print(df6.empty)
# Out:
# False

# %%
print(df6.ndim)
# Out:
# 2

# %%
print(df6.shape)
# Out:
# (6, 4)

# %%
print(df6.size)
# Out:
# 24

# %%
print(df6.values)
# Out:
# [['Ahmet' 25 33.0 'Ankara']
#  ['Mehmet' 26 67.2 'Konya']
#  ['Ayşe' 27 55.5 'Denizli']
#  ['Fatma' 25 67.8 'Ankara']
#  ['Cevdet' 34 98.1 'Ankara']
#  ['Süleyman' 32 66.2 'Bursa']]

# %%
print(df6.head())
# Out:
#      İsim  Yaş   Not Memleket
# 0   Ahmet   25  33.0   Ankara
# 1  Mehmet   26  67.2    Konya
# 2    Ayşe   27  55.5  Denizli
# 3   Fatma   25  67.8   Ankara
# 4  Cevdet   34  98.1   Ankara

# %%
print(df6.tail())
# Out:
#        İsim  Yaş   Not Memleket
# 1    Mehmet   26  67.2    Konya
# 2      Ayşe   27  55.5  Denizli
# 3     Fatma   25  67.8   Ankara
# 4    Cevdet   34  98.1   Ankara
# 5  Süleyman   32  66.2    Bursa

# %%
print(df6.sum())
# Out:
# İsim         AhmetMehmetAyşeFatmaCevdetSüleyman
# Yaş                                         169
# Not                                       387.8
# Memleket    AnkaraKonyaDenizliAnkaraAnkaraBursa
# dtype: object

# %%
print(df6.sum(1))
# Out:
# 0     58.0
# 1     93.2
# 2     82.5
# 3     92.8
# 4    132.1
# 5     98.2
# dtype: float64

# %%
print(df6)
# Out:
#        İsim  Yaş   Not Memleket
# 0     Ahmet   25  33.0   Ankara
# 1    Mehmet   26  67.2    Konya
# 2      Ayşe   27  55.5  Denizli
# 3     Fatma   25  67.8   Ankara
# 4    Cevdet   34  98.1   Ankara
# 5  Süleyman   32  66.2    Bursa

# %%
print(df6.mean())
# Out:
# Yaş    28.166667
# Not    64.633333
# dtype: float64

# %%
print(df6.std())
# Out:
# Yaş     3.868678
# Not    21.086362
# dtype: float64

# %%
print(df6.count())
# Out:
# İsim        6
# Yaş         6
# Not         6
# Memleket    6
# dtype: int64

# %%
print(df6.median())
# Out:
# Yaş    26.5
# Not    66.7
# dtype: float64

# %%
print(df6.mode())
# Out:
#        İsim   Yaş   Not Memleket
# 0     Ahmet  25.0  33.0   Ankara
# 1      Ayşe   NaN  55.5      NaN
# 2    Cevdet   NaN  66.2      NaN
# 3     Fatma   NaN  67.2      NaN
# 4    Mehmet   NaN  67.8      NaN
# 5  Süleyman   NaN  98.1      NaN

# %%
print(df6.min())
# Out:
# İsim         Ahmet
# Yaş             25
# Not           33.0
# Memleket    Ankara
# dtype: object

# %%
print(df6.max())
# Out:
# İsim        Süleyman
# Yaş               34
# Not             98.1
# Memleket       Konya
# dtype: object

# %%
print(df6.prod())
# Out:
# Yaş    4.773600e+08
# Not    5.419171e+10
# dtype: float64

# %%
print(df6.cumsum())
# Out:
#                                  İsim  Yaş    Not  \
# 0                               Ahmet   25   33.0
# 1                         AhmetMehmet   51  100.2
# 2                     AhmetMehmetAyşe   78  155.7
# 3                AhmetMehmetAyşeFatma  103  223.5
# 4          AhmetMehmetAyşeFatmaCevdet  137  321.6
# 5  AhmetMehmetAyşeFatmaCevdetSüleyman  169  387.8
#
#                               Memleket
# 0                               Ankara
# 1                          AnkaraKonya
# 2                   AnkaraKonyaDenizli
# 3             AnkaraKonyaDenizliAnkara
# 4       AnkaraKonyaDenizliAnkaraAnkara
# 5  AnkaraKonyaDenizliAnkaraAnkaraBursa

# %%
print(df6.describe())
# Out:
#              Yaş        Not
# count   6.000000   6.000000
# mean   28.166667  64.633333
# std     3.868678  21.086362
# min    25.000000  33.000000
# 25%    25.250000  58.175000
# 50%    26.500000  66.700000
# 75%    30.750000  67.650000
# max    34.000000  98.100000

# %%
print(df6.describe(include='all'))
# Out:
#           İsim        Yaş        Not Memleket
# count        6   6.000000   6.000000        6
# unique       6        NaN        NaN        4
# top     Mehmet        NaN        NaN   Ankara
# freq         1        NaN        NaN        3
# mean       NaN  28.166667  64.633333      NaN
# std        NaN   3.868678  21.086362      NaN
# min        NaN  25.000000  33.000000      NaN
# 25%        NaN  25.250000  58.175000      NaN
# 50%        NaN  26.500000  66.700000      NaN
# 75%        NaN  30.750000  67.650000      NaN
# max        NaN  34.000000  98.100000      NaN

# %%
import numpy as np
yeni_df = pd.DataFrame(np.random.randn(5,3), columns=['sütun1','sütun2','sütun3'])
print(yeni_df)
yeni_df.apply(np.mean)
print(yeni_df.apply(np.mean))
# Out:
#      sütun1    sütun2    sütun3
# 0 -0.191684 -0.718021  1.453400
# 1 -0.755155  0.745710  1.542789
# 2  1.218087  1.202469  1.980975
# 3  0.608251 -0.121722 -0.246911
# 4  0.193250  1.097993 -1.948207
# sütun1    0.214550
# sütun2    0.441286
# sütun3    0.556409
# dtype: float64

# %%
yeni_df.apply(np.mean, axis = 1)
print(yeni_df.apply(np.mean, axis = 1))
# Out:
# 0    0.181232
# 1    0.511115
# 2    1.467177
# 3    0.079873
# 4   -0.218988
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

df2 = pd.DataFrame(np.random.randn(7,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df2)
# Out:
#      sütun1    sütun2    sütun3
# 0  1.618016  0.209349 -0.758017
# 1 -0.688665 -0.824733  1.432722
# 2  0.960830 -0.193244  0.148723
# 3  1.212994  0.072450  2.015749
# 4  0.616094  2.028129 -1.896713
# 5  2.653449 -0.551366  0.483879
# 6 -0.336808 -2.059716 -1.165702
# 7 -1.198321  0.995901  1.136708
# 8  0.225590 -0.626583 -0.375465
# 9 -0.830680 -1.563912  0.988775
#      sütun1    sütun2    sütun3
# 0 -1.218354  2.052281 -0.399956
# 1 -0.027928  0.068622  0.333883
# 2  0.611194 -0.791458 -0.405006
# 3  0.172678  0.045447  0.415077
# 4  0.241924 -2.135295 -1.928785
# 5 -2.068647 -2.155207  0.276484
# 6 -1.046798 -1.090831  2.174706

# %%
df1 = df1.reindex_like(df2)
print(df1)
# Out:
#      sütun1    sütun2    sütun3
# 0  1.618016  0.209349 -0.758017
# 1 -0.688665 -0.824733  1.432722
# 2  0.960830 -0.193244  0.148723
# 3  1.212994  0.072450  2.015749
# 4  0.616094  2.028129 -1.896713
# 5  2.653449 -0.551366  0.483879
# 6 -0.336808 -2.059716 -1.165702

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

df2 = pd.DataFrame(np.random.randn(7,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df2)
# Out:
#      sütun1    sütun2    sütun3
# 0 -0.137433 -1.728186 -0.909010
# 1 -0.536417 -0.416036  0.517949
# 2  1.198116 -0.155563 -0.611059
# 3  0.529386 -0.834286  1.053919
# 4  0.270138  0.614494  0.815396
# 5  1.290591 -0.400532  1.003617
# 6  2.367549 -0.053023  0.853456
# 7  1.092268 -1.189588  1.488802
# 8 -1.334334  1.223613 -0.353648
# 9  0.825430 -0.574850  0.967691
#      sütun1    sütun2    sütun3
# 0 -1.824346 -1.183103  1.353693
# 1  1.003409 -0.532267 -0.785582
# 2  1.241321 -1.204266  0.727532
# 3 -0.753525  0.771147 -0.370558
# 4  0.246200  0.613632  0.350649
# 5 -0.599031 -1.303693  1.543023
# 6  0.694764 -0.224399  0.351961

# %%
df2 = df2.reindex_like(df1,method='ffill',limit=1)
print(df2)
# Out:
#      sütun1    sütun2    sütun3
# 0 -1.824346 -1.183103  1.353693
# 1  1.003409 -0.532267 -0.785582
# 2  1.241321 -1.204266  0.727532
# 3 -0.753525  0.771147 -0.370558
# 4  0.246200  0.613632  0.350649
# 5 -0.599031 -1.303693  1.543023
# 6  0.694764 -0.224399  0.351961
# 7  0.694764 -0.224399  0.351961
# 8       NaN       NaN       NaN
# 9       NaN       NaN       NaN

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

print (df1.rename(columns={'sütun1' : 'c1', 'sütun2' : 'c2'},
                  index={0: 'Lale', 1: 'Sümbül'} ))
# Out:
#      sütun1    sütun2    sütun3
# 0  1.328933 -0.812806 -0.885498
# 1  0.367680 -0.016006 -0.301820
# 2  1.383250 -0.943890  0.369173
# 3  1.984697  2.556352 -1.494871
# 4 -0.635298  1.068213 -1.423036
# 5  0.035920  0.436124 -1.600639
# 6  1.267116  0.173415  0.335559
# 7  0.209371 -0.530489  0.157558
# 8  0.751875 -0.348967  0.030540
# 9  1.723388 -0.028629  0.525445
#               c1        c2    sütun3
# Lale    1.328933 -0.812806 -0.885498
# Sümbül  0.367680 -0.016006 -0.301820
# 2       1.383250 -0.943890  0.369173
# 3       1.984697  2.556352 -1.494871
# 4      -0.635298  1.068213 -1.423036
# 5       0.035920  0.436124 -1.600639
# 6       1.267116  0.173415  0.335559
# 7       0.209371 -0.530489  0.157558
# 8       0.751875 -0.348967  0.030540
# 9       1.723388 -0.028629  0.525445

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

for anahtar, deger in df1.iteritems():
    print (anahtar, deger)
# Out:
#      sütun1    sütun2    sütun3
# 0  0.799265  1.634331 -0.371627
# 1  1.121379  0.674432 -0.148174
# 2  0.032910  0.130083  1.571694
# 3 -0.111707  0.104081 -0.615222
# 4  0.265883 -1.195297 -0.574539
# 5  1.457253 -0.250536 -0.518249
# 6  0.335362 -0.304764 -0.726963
# 7  0.757201 -1.318056 -0.709656
# 8  0.654875  1.164042  0.306689
# 9  1.626034  0.954986  0.358712
# sütun1 0    0.799265
# 1    1.121379
# 2    0.032910
# 3   -0.111707
# 4    0.265883
# 5    1.457253
# 6    0.335362
# 7    0.757201
# 8    0.654875
# 9    1.626034
# Name: sütun1, dtype: float64
# sütun2 0    1.634331
# 1    0.674432
# 2    0.130083
# 3    0.104081
# 4   -1.195297
# 5   -0.250536
# 6   -0.304764
# 7   -1.318056
# 8    1.164042
# 9    0.954986
# Name: sütun2, dtype: float64
# sütun3 0   -0.371627
# 1   -0.148174
# 2    1.571694
# 3   -0.615222
# 4   -0.574539
# 5   -0.518249
# 6   -0.726963
# 7   -0.709656
# 8    0.306689
# 9    0.358712
# Name: sütun3, dtype: float64

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

for satir_indeksi, satir in df1.iterrows():
    print (satir_indeksi, satir)
# Out:
#      sütun1    sütun2    sütun3
# 0 -0.701987  1.914854 -0.377465
# 1  0.237779  0.385613  0.610003
# 2 -0.468231  0.830290  0.815377
# 3  0.314605  0.992099 -1.017654
# 4 -0.760466 -1.468634 -0.157616
# 5 -0.865194 -0.476801 -1.108677
# 6  0.461767  2.283532 -0.696150
# 7  0.671543  1.840931  0.424441
# 8  0.561397 -0.032636 -0.296144
# 9 -0.741622 -0.645232  0.289176
# 0 sütun1   -0.701987
# sütun2    1.914854
# sütun3   -0.377465
# Name: 0, dtype: float64
# 1 sütun1    0.237779
# sütun2    0.385613
# sütun3    0.610003
# Name: 1, dtype: float64
# 2 sütun1   -0.468231
# sütun2    0.830290
# sütun3    0.815377
# Name: 2, dtype: float64
# 3 sütun1    0.314605
# sütun2    0.992099
# sütun3   -1.017654
# Name: 3, dtype: float64
# 4 sütun1   -0.760466
# sütun2   -1.468634
# sütun3   -0.157616
# Name: 4, dtype: float64
# 5 sütun1   -0.865194
# sütun2   -0.476801
# sütun3   -1.108677
# Name: 5, dtype: float64
# 6 sütun1    0.461767
# sütun2    2.283532
# sütun3   -0.696150
# ...

# %%
df1 = pd.DataFrame(np.random.randn(10,3), columns = ['sütun1', 'sütun2', 'sütun3'])
print(df1)

for satir in df1.itertuples():
    print (satir)
# Out:
#      sütun1    sütun2    sütun3
# 0  0.068875 -0.164588 -0.216991
# 1 -0.134667 -2.384179 -0.520087
# 2  0.871878 -0.868175 -2.329794
# 3 -0.168748 -1.642454  0.074179
# 4 -0.356394  1.339944  0.779816
# 5 -1.195533 -0.768512 -2.549724
# 6 -1.996057 -1.260606  0.231606
# 7 -0.931436 -0.041088 -0.351548
# 8 -0.992659 -0.393270 -0.140245
# 9 -0.633427 -2.008713 -0.019244
# Pandas(Index=0, sütun1=0.06887495173767764, sütun2=-0.16458828913113047, sütun3=-0.216991489152364)
# Pandas(Index=1, sütun1=-0.134667494186076, sütun2=-2.384179318423814, sütun3=-0.5200874879919387)
# Pandas(Index=2, sütun1=0.8718777994510946, sütun2=-0.8681749212300741, sütun3=-2.329794442690248)
# Pandas(Index=3, sütun1=-0.16874776905128178, sütun2=-1.6424536040021425, sütun3=0.07417884917085926)
# Pandas(Index=4, sütun1=-0.35639363020400683, sütun2=1.3399441687787965, sütun3=0.7798157581090571)
# Pandas(Index=5, sütun1=-1.1955330879050967, sütun2=-0.7685120179330389, sütun3=-2.549723879854984)
# ...

# %%
import numpy as np
sirasiz_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,3,2,9,7,8,6,5,0],columns=['sütun2', 'sütun1'])
print(sirasiz_df)
# Out:
#      sütun2    sütun1
# 1 -0.365298  0.453668
# 4  0.717680  0.717843
# 3  0.264191  0.314766
# 2 -0.348544 -1.316944
# 9 -0.632068 -1.050465
# 7  0.778007  2.184285
# 8 -0.553399  0.467087
# 6  0.740281 -1.063944
# 5 -0.030467  1.892678
# 0 -0.634520  0.164552

# %%
sirali_df = sirasiz_df.sort_index(axis = 1)
print(sirali_df)
# Out:
#      sütun1    sütun2
# 1  0.453668 -0.365298
# 4  0.717843  0.717680
# 3  0.314766  0.264191
# 2 -1.316944 -0.348544
# 9 -1.050465 -0.632068
# 7  2.184285  0.778007
# 8  0.467087 -0.553399
# 6 -1.063944  0.740281
# 5  1.892678 -0.030467
# 0  0.164552 -0.634520

# %%
sirasiz_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,3,2,9,7,8,6,5,0],columns=['sütun2', 'sütun1'])
print(sirasiz_df)
sirali_df = sirasiz_df.sort_values(by='sütun1')
print(sirali_df)
# Out:
#      sütun2    sütun1
# 1 -0.102225 -0.458205
# 4 -0.693998 -0.587165
# 3  1.738340 -0.930213
# 2 -0.021677  1.247927
# 9 -1.309557  0.350964
# 7  1.096850 -2.059770
# 8 -0.746112 -0.766341
# 6 -0.947203  1.874502
# 5  1.179831  0.932445
# 0 -0.249430 -0.100323
#      sütun2    sütun1
# 7  1.096850 -2.059770
# 3  1.738340 -0.930213
# 8 -0.746112 -0.766341
# 4 -0.693998 -0.587165
# 1 -0.102225 -0.458205
# 0 -0.249430 -0.100323
# 9 -1.309557  0.350964
# 5  1.179831  0.932445
# 2 -0.021677  1.247927
# 6 -0.947203  1.874502

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16],'r<-')
plt.xlabel('Tamsayılar')
plt.ylabel('Tamsayıların Kareleri')
plt.title('Bazı tamsayıların kareleri')
plt.show()

# %%
import numpy as np
t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, 'ro--', t, t**2, 'bs', t, t**3, 'k>-', t, (3*t)+4, 'g')
plt.show()

# %%
veri = {'a': np.arange(50),
        'c': np.random.randint(0,50,50),
        'd': np.random.randn(50)}
veri['b'] = veri['a'] + (10 * np.random.randn(50))
veri['d'] = np.abs(veri['d']) * 100

plt.scatter('a','b', c='c', s='d', data = veri)
plt.xlabel('a sütunundaki veriler')
plt.ylabel('b sütunundaki veriler')
plt.show()

# %%
isimler = ['Ahmet', 'Mehmet', 'Ayşe', 'Fatma']
degerler = [5, 25, 50, 100]

plt.figure(figsize=(9,3))

plt.subplot(131)
plt.bar(isimler, degerler)

plt.subplot(132)
plt.scatter(isimler, degerler)

plt.subplot(133)
plt.plot(isimler, degerler)

plt.suptitle('Birçok Farklı Grafik')
plt.show()

# %%
import numpy as np
t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, 'b', linewidth=2.0)
plt.show()

# %%
t = np.arange(0.0, 5.0, 0.1)
plt.plot(t, (np.exp(-t) * np.cos(2 * np.pi * t)), 'k', 
         t, (np.exp(-t) *  np.cos(2 * np.pi * t)), 'bo')
plt.axis([0, 5, -1, 1])

plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)

# fonksiyonun tanımlanması
def UydurmasyonFonksiyonHesapla(girdi_parametre1, girdi_parametre2):
    # birtakım işlemler
    return cikti_parametre1, cikti_parametre2, cikti_parametre3  

# tanımlı fonksiyonun çağrılması
cikti1, cikti2, cikti3 = UydurmasyonFonksiyonHesapla(girdi1, girdi2)


t = np.arange(0.0, 5.0, 0.1)
plt.plot(t, f(t), 'k', t, f(t), 'bo')
plt.axis([0, 10, -1, 1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       7     return cikti_parametre1, cikti_parametre2, cikti_parametre3
#       9 # tanımlı fonksiyonun çağrılması
# ---> 10 cikti1, cikti2, cikti3 = UydurmasyonFonksiyonHesapla(girdi1, girdi2)
#      13 t = np.arange(0.0, 5.0, 0.1)
#      14 plt.plot(t, f(t), 'k', t, f(t), 'bo')
#
# NameError: name 'girdi1' is not defined

# %%
mu1 = 100
sigma1 = 15
x = mu1 + (sigma1 * np.random.randn(10000))

mu2 = 110
sigma2 = 10
y = mu2 + (sigma2 * np.random.randn(10000))

# söz konusu verilerin histogramı
n, bins, patches = plt.hist(x, 100, density = 1, facecolor='b', alpha=0.25)
n, bins, patches = plt.hist(y, 100, density = 1, facecolor='g', alpha=0.25)

plt.xlabel('Veriler')
plt.ylabel('Olasılıklar')
plt.title(r'Verilerin Histogramı: $\mu_1=100,\ \mu_2=110$')
plt.annotate('Gauss eğrisinin tepesi', xy=(110,0.04), xytext=(130,0.045),
             arrowprops=dict(facecolor='black', shrink=0.1))
plt.text(75, 0.025, r'$\mu_1=100,\ \sigma_1=15$')
plt.text(120, 0.035, r'$\mu_2=110,\ \sigma_2=10$')
plt.axis([40, 160, 0, 0.05])
plt.grid(True)
plt.show()

# %%
x = np.arange(0,10,0.01)
y = np.exp(x)


plt.figure()

plt.subplot(121)
plt.plot(x,y)
plt.yscale('linear')
plt.title('Lineer (Doğrusal)')
plt.grid(True)

plt.subplot(122)
plt.plot(x,y)
plt.yscale('log')
plt.title('Logaritmik')
plt.grid(True)

# plt.subplots_adjust(top=0.98, bottom=0.02, left=0.02, right=0.98, hspace=0.05)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

veri = pd.read_csv("olimpiyatlar_temizlenmis.csv")
veri.head()
# Out:
#                        isim cinsiyet   yas     boy   kilo           takim  \
# 0      Edgar Lindenau Aabye        M  34.0  182.48  95.62  Denmark/Sweden
# 1      Arvo Ossian Aaltonen        M  30.0  182.01  76.69         Finland
# 2      Arvo Ossian Aaltonen        M  30.0  177.00  75.00         Finland
# 3  Juhamatti Tapio Aaltonen        M  28.0  184.00  85.00         Finland
# 4   Paavo Johannes Aaltonen        M  28.0  175.00  64.00         Finland
#
#    uok   yil   sezon      sehir        spor  \
# 0  DEN  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948  Summer     London  Gymnastics
#
#                                  etkinlik madalya
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
veri.tail()
# Out:
#                                       isim cinsiyet   yas    boy  kilo  \
# 39778  Galina Ivanovna Zybina (-Fyodorova)        F  25.0  168.0  80.0
# 39779  Galina Ivanovna Zybina (-Fyodorova)        F  33.0  168.0  80.0
# 39780                         Bogusaw Zych        M  28.0  182.0  82.0
# 39781            Olesya Nikolayevna Zykina        F  19.0  171.0  64.0
# 39782            Olesya Nikolayevna Zykina        F  23.0  171.0  64.0
#
#               takim  uok   yil   sezon      sehir       spor  \
# 39778  Soviet Union  URS  1956  Summer  Melbourne  Athletics
# 39779  Soviet Union  URS  1964  Summer      Tokyo  Athletics
# 39780        Poland  POL  1980  Summer     Moskva    Fencing
# 39781        Russia  RUS  2000  Summer     Sydney  Athletics
# 39782        Russia  RUS  2004  Summer     Athina  Athletics
#
#                                      etkinlik madalya
# 39778              Athletics Women's Shot Put  Silver
# 39779              Athletics Women's Shot Put  Bronze
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39783 entries, 0 to 39782
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   isim      39783 non-null  object
#  1   cinsiyet  39783 non-null  object
#  2   yas       39783 non-null  float64
#  3   boy       39783 non-null  float64
#  4   kilo      39783 non-null  float64
#  5   takim     39783 non-null  object
#  6   uok       39783 non-null  object
#  7   yil       39783 non-null  int64
#  8   sezon     39783 non-null  object
#  9   sehir     39783 non-null  object
#  10  spor      39783 non-null  object
#  11  etkinlik  39783 non-null  object
#  12  madalya   39783 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 3.9+ MB

# %%
veri.describe()
# Out:
#                 yas           boy          kilo           yil
# count  39783.000000  39783.000000  39783.000000  39783.000000
# mean      25.918456    177.336690     73.738320   1973.943845
# std        5.859569     10.170124     13.979041     33.822857
# min       10.000000    136.000000     28.000000   1896.000000
# 25%       22.000000    170.000000     64.000000   1952.000000
# 50%       25.000000    177.480000     73.000000   1984.000000
# 75%       29.000000    184.000000     82.000000   2002.000000
# max       73.000000    223.000000    182.000000   2016.000000

# %%
veri.describe(include='all')
# Out:
#                            isim cinsiyet           yas           boy  \
# count                     39783    39783  39783.000000  39783.000000
# unique                    28202        2           NaN           NaN
# top     Michael Fred Phelps, II        M           NaN           NaN
# freq                         28    28530           NaN           NaN
# mean                        NaN      NaN     25.918456    177.336690
# std                         NaN      NaN      5.859569     10.170124
# min                         NaN      NaN     10.000000    136.000000
# 25%                         NaN      NaN     22.000000    170.000000
# 50%                         NaN      NaN     25.000000    177.480000
# 75%                         NaN      NaN     29.000000    184.000000
# max                         NaN      NaN     73.000000    223.000000
#
#                 kilo          takim    uok           yil   sezon   sehir  \
# ...

# %%
plt.scatter('boy','kilo',data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('SporcularınAğırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
import seaborn as sns

sns.set_style("whitegrid")

sns.scatterplot(x='boy',y='kilo', data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("darkgrid")

sns.scatterplot(x='boy',y='kilo', data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy',y='kilo', hue='cinsiyet', data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy',y='kilo',hue='cinsiyet',style='madalya',data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy',y='kilo',hue='madalya',style='cinsiyet',size='yas',sizes=(15,200),data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.scatterplot(x='boy',y='kilo',hue='cinsiyet',style='madalya',size='yas',sizes=(15,200),data=veri,palette="rocket")
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.lineplot(x='boy', y='kilo', hue='madalya', data=veri)
plt.xlabel('Sporcuların Boyu')
plt.ylabel('Sporcuların Ağırlığı')
plt.title('Madalyalı Sporcuların Ağırlık-Boy Değişimleri')
plt.show()

# %%
sns.set_style("whitegrid")

sns.displot(veri, x='boy', hue='cinsiyet')
plt.ylabel('Frekans')
plt.title('Madalyalı Sporcuların Boylarının Histogramı')
plt.show()

# %%
sns.set_style("whitegrid")

sns.displot(veri, x='boy', hue='cinsiyet', multiple="dodge")
plt.ylabel('Frekans')
plt.title('Madalyalı Sporcuların Boylarının Histogramı')
plt.show()

# %%
sns.set_style("whitegrid")

sns.displot(veri, x='boy', y='kilo', kind='kde')
plt.ylabel('Frekans')
plt.title('Madalyalı Sporcuların Kilo-Boy Histogramı')
plt.show()

# %%
sns.set_style("whitegrid")

sns.kdeplot(data = veri, x='boy', y='kilo', hue='cinsiyet', fill=True)
plt.ylabel('Ağırlık')
plt.ylabel('Boy')
plt.title('Madalyalı Sporcuların Kilo-Boy Histogramı')
plt.show()

# %%
sns.barplot(x='madalya', y='boy', data=veri)
plt.title('Madalyalara Göre Boy Grafiği')
plt.show()

# %%
sns.barplot(x='madalya', y='boy', data=veri, hue='cinsiyet')
plt.title('Madalyalara Göre Boy Grafiği (Cinsiyete Göre Ayrıştırılmış)')
plt.show()

# %%
sns.barplot(x='madalya', y='yas', data=veri, hue='sezon')
plt.title('Madalyalara Göre Boy Grafiği (Sezona Göre Ayrıştırılmış)')
plt.show()

# %%
sns.catplot(x='madalya', y='yas', hue='cinsiyet', col='sezon', data=veri, kind='bar')

# %%
sns.boxplot(x='sezon', y='kilo', hue='cinsiyet', data=veri, palette='Set2')
plt.show()

# %%
gecici_veri = veri.loc[:,["yas","boy","kilo"]]

# %%
gecici_veri.head()
# Out:
#     yas     boy   kilo
# 0  34.0  182.48  95.62
# 1  30.0  182.01  76.69
# 2  30.0  177.00  75.00
# 3  28.0  184.00  85.00
# 4  28.0  175.00  64.00

# %%
sns.boxplot(data=gecici_veri, palette='Set2')
# Out:
# <Axes: >

# %%
sns.boxplot(data=gecici_veri, orient = 'h', palette='Set2')
# Out:
# <Axes: >

# %%
sns.catplot(x="sezon", y="boy", hue="cinsiyet", col="madalya", data=veri, kind="box")

# %%
sns.heatmap(veri.corr(), annot=True, linewidths=0.5, fmt='.1f')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.heatmap(veri.corr(), annot=True, linewidths=0.5, fmt='.1f')
#       2 plt.show()
#
# File c:\Users\excal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\excal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
sns.violinplot(x = "sezon", y = "boy", data = veri)
plt.show()

# %%
sns.violinplot(x = "sezon", y = "boy", data = veri, hue="cinsiyet", split=True)
plt.show()

# %%
sns.catplot(x = "sezon", y = "boy", hue="cinsiyet", col = "madalya", data = veri, kind = "violin", split=True)
plt.show()

# %%
sns.catplot(x = "sezon", y = "boy", hue="cinsiyet", col = "madalya", data = veri, kind = "violin")
plt.show()

# %%
sns.jointplot(data=veri, x="kilo", y="boy", hue="sezon", kind="kde")
plt.show()

# %%
g = sns.JointGrid(data=veri, x="kilo", y="boy")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %%
sns.pairplot(veri)
plt.show()

# %%
g = sns.PairGrid(veri)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill = True)
g.map_diag(sns.histplot, kde=True)

# %%
sns.countplot(x="sehir", data=veri)
plt.xticks(rotation = 90)
plt.show()

# %%
import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(df.query("year==2002"), x="gdpPercap", y="lifeExp",
	         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()

# %%
print(df)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df.describe(include='all')
# Out:
#             country continent        year      lifeExp           pop  \
# count          1704      1704  1704.00000  1704.000000  1.704000e+03
# unique          142         5         NaN          NaN           NaN
# top     Afghanistan    Africa         NaN          NaN           NaN
# freq             12       624         NaN          NaN           NaN
# mean            NaN       NaN  1979.50000    59.474439  2.960121e+07
# std             NaN       NaN    17.26533    12.917107  1.061579e+08
# min             NaN       NaN  1952.00000    23.599000  6.001100e+04
# 25%             NaN       NaN  1965.75000    48.198000  2.793664e+06
# 50%             NaN       NaN  1979.50000    60.712500  7.023596e+06
# 75%             NaN       NaN  1993.25000    70.845500  1.958522e+07
# max             NaN       NaN  2007.00000    82.603000  1.318683e+09
#
#             gdpPercap iso_alpha      iso_num
# count     1704.000000      1704  1704.000000
# unique            NaN       141          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
df.to_excel('gpd-veri-seti.xlsx', engine='xlsxwriter')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.to_excel('gpd-veri-seti.xlsx', engine='xlsxwriter')
#
# File c:\Users\excal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_matrix(df)
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_matrix(df,
    dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"],
    color="species")
fig.show()

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")
fig = px.scatter_geo(df, locations="iso_alpha",
                     size="pop", # size of markers, "pop" is one of the columns of gapminder
                     )
fig.show()

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")
fig = px.scatter_geo(df, locations="iso_alpha",
                     color="continent", # which column to use to set the color of markers
                     hover_name="country", # column added to hover information
                     size="pop", # size of markers
                     projection="natural earth")
fig.show()

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df['text'] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        text = df['text'],
        mode = 'markers',
        marker_color = df['cnt'],
        ))

fig.update_layout(
        title = 'Most trafficked US airports<br>(Hover for airport names)',
        geo_scope='usa',
    )
fig.show()

# %%
import plotly.express as px
data = dict(
    character=["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"],
    parent=["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve" ],
    value=[10, 14, 12, 10, 2, 6, 6, 4, 4])

fig = px.sunburst(
    data,
    names='character',
    parents='parent',
    values='value',
)
fig.show()
